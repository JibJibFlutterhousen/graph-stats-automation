# %%
import re
import math
import csv

import networkx as nx
import matplotlib.pyplot as plt

# %%
counter = 0
with open("stats.csv", "w") as out_file:
    out_file.write("Graph Name (top center),Size (top left),Order (top right),Number of connected components (bottom right),Planarity (bottom left)\n")
    with open("graph6.g6", "rb") as in_file:
        for graph6_bytes in in_file:
            counter += 1
            graph = nx.from_graph6_bytes(graph6_bytes.strip())
            size = graph.number_of_nodes()
            order = graph.number_of_edges()
            components = nx.number_connected_components(graph)
            planar = nx.is_planar(graph)
            out_file.write("$G_{"+f"{counter}"+"}$,"+f"{graph6_bytes.strip().decode()},{size},{order},{components},{planar}\n")

# %%
def cell_wrapper(graph, graph_name = None, lower_left = None, lower_right = None, upper_left = None, upper_right = None):
    graph_layout = nx.kamada_kawai_layout(graph)
    
    node_styles=dict()
    default_node_style = "draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt"
    meta_node_style = "shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1"
    for node in graph:
        node_styles[node] = default_node_style
    
    tikz_code = re.sub(r'\{\d+\}', '{}', nx.to_latex_raw(graph, pos=graph_layout, node_options=node_styles)).strip()

    tikz_picture_code = r"\resizebox{1in}{!}{tikz_code}".replace('tikz_code',tikz_code)
    
    if graph_name is not None:
        name_label = max(int(x) for x in re.findall(r'\((\d+)\)', tikz_picture_code))+1
        graph_name_line = f"      \draw\n        (0.0,1.35) node[{meta_node_style}]" + f"({name_label})" + r" {\textbf{" + f"{graph_name}" + "}};\n"
        lines = tikz_picture_code.split("\n")
        tikz_picture_code = ""
        for line in lines:
            if r"\begin{scope}[-]" in line:
                tikz_picture_code += graph_name_line
            tikz_picture_code += line
            if r"    \end{tikzpicture}}" in line:
                break
            else:
                tikz_picture_code += "\n"
    
    if lower_left is not None:
        name_label = max(int(x) for x in re.findall(r'\((\d+)\)', tikz_picture_code))+1
        graph_name_line = f"      \draw\n        (-1.0,-1.15) node[{meta_node_style}]" + f"({name_label})" + r" {" + f"{lower_left}" + "};\n"
        lines = tikz_picture_code.split("\n")
        tikz_picture_code = ""
        for line in lines:
            if r"\begin{scope}[-]" in line:
                tikz_picture_code += graph_name_line
            tikz_picture_code += line
            if r"    \end{tikzpicture}}" in line:
                break
            else:
                tikz_picture_code += "\n"
    
    if upper_left is not None:
        name_label = max(int(x) for x in re.findall(r'\((\d+)\)', tikz_picture_code))+1
        graph_name_line = f"      \draw\n        (-1.0,1.35) node[{meta_node_style}]" + f"({name_label})" + r" {" + f"{upper_left}" + "};\n"
        lines = tikz_picture_code.split("\n")
        tikz_picture_code = ""
        for line in lines:
            if r"\begin{scope}[-]" in line:
                tikz_picture_code += graph_name_line
            tikz_picture_code += line
            if r"    \end{tikzpicture}}" in line:
                break
            else:
                tikz_picture_code += "\n"
    
    if lower_right is not None:
        name_label = max(int(x) for x in re.findall(r'\((\d+)\)', tikz_picture_code))+1
        graph_name_line = f"      \draw\n        (1.0,-1.15) node[{meta_node_style}]" + f"({name_label})" + r" {" + f"{lower_right}" + "};\n"
        lines = tikz_picture_code.split("\n")
        tikz_picture_code = ""
        for line in lines:
            if r"\begin{scope}[-]" in line:
                tikz_picture_code += graph_name_line
            tikz_picture_code += line
            if r"    \end{tikzpicture}}" in line:
                break
            else:
                tikz_picture_code += "\n"
    
    if upper_right is not None:
        name_label = max(int(x) for x in re.findall(r'\((\d+)\)', tikz_picture_code))+1
        graph_name_line = f"      \draw\n        (1.0,1.35) node[{meta_node_style}]" + f"({name_label})" + r" {" + f"{upper_right}" + "};\n"
        lines = tikz_picture_code.split("\n")
        tikz_picture_code = ""
        for line in lines:
            if r"\begin{scope}[-]" in line:
                tikz_picture_code += graph_name_line
            tikz_picture_code += line
            if r"    \end{tikzpicture}}" in line:
                break
            else:
                tikz_picture_code += "\n"
            

    return tikz_picture_code

# print(cell_wrapper(nx.complete_graph(8), graph_name=r"$K_{10}$", upper_left="a", upper_right="b", lower_left="c", lower_right="d"))
# print("happy")

# %%
def table_wrapper(stats_file):
    longtable_code = r"""\begin{longtable}{|c|c|c|c|c|c|}
\hline
"""
    with open(stats_file, "r") as in_file:
        csv_reader = csv.reader(in_file)
        first = True
        counter = 0
        number_of_lines = sum(1 for dummy in in_file)-1
        in_file.seek(0)
        for line in csv_reader:
            if first:
                first = False
                continue
            else:
                graph_name = line[0]
                graph = nx.from_graph6_bytes(line[1].encode())
                top_left = None
                top_right = None
                bottom_right = None
                bottom_left = None
                if len(line) > 2:
                    top_left = line[2]
                if len(line) > 3:
                    top_right = line[3]
                if len(line) > 4:
                    bottom_right = line[4]
                if len(line) > 5:
                    bottom_left = line[5]
                longtable_code += cell_wrapper(graph, graph_name=graph_name, upper_left=top_left, upper_right=top_right, lower_right=bottom_right, lower_left=bottom_left)
                counter += 1
                if counter == number_of_lines:
                    longtable_code += "\n"
                    break
                if counter % 6 == 0:
                    longtable_code += r"""\\ \hline
"""
                else:
                    longtable_code += "&"
    longtable_code += r"""\\ \hline
\end{longtable}
"""
    return longtable_code

print(table_wrapper("stats.csv"))
# Out:
# \begin{longtable}{|c|c|c|c|c|c|}
# \hline
# \resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, 0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.5, 0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.5, 0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.5, -0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.5, -0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{1}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {6};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {0};
#       \begin{scope}[-]
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, 0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.5, 0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.5, 0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.5, -0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.5, -0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{2}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {5};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {1};
#       \begin{scope}[-]
#         \draw (0) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, -0.429) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (-0.076, 0.434) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.345, 0.598) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.69, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.345, -0.598) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.456, -0.005) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{3}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {4};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {2};
#       \begin{scope}[-]
#         \draw (0) to (5);
#         \draw (1) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.851, -0.526) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.655, 1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.569, 0.067) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.833, 0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.417, -0.722) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.312, 0.18) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{4}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {3};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {3};
#       \begin{scope}[-]
#         \draw (0) to (5);
#         \draw (1) to (5);
#         \draw (2) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.925, -0.59) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.869, 1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.721, 0.943) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.665, -0.647) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.51, -0.883) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.102, 0.177) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{5}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {2};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {4};
#       \begin{scope}[-]
#         \draw (0) to (5);
#         \draw (1) to (5);
#         \draw (2) to (5);
#         \draw (3) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.919, -0.409) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.673, 0.747) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.503, 0.871) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.984, -0.209) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.105, -1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.0, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{6}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {5};
#       \begin{scope}[-]
#         \draw (0) to (5);
#         \draw (1) to (5);
#         \draw (2) to (5);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}\\ \hline
# \resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.683, -0.183) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.5, 0.5) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.5, 0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.183, -0.683) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.5, -0.5) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{7}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {4};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {2};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (1) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.594, -0.159) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (1.0, 0.407) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.712, 0.104) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.869, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.159, -0.594) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.146, 0.243) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{8}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {3};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {3};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (1) to (5);
#         \draw (2) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.599, -0.161) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.826, 0.19) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.577, 1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.577, -0.62) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.161, -0.599) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.11, 0.19) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{9}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {2};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {4};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (1) to (5);
#         \draw (2) to (5);
#         \draw (3) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.577, -0.072) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.464, 0.804) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.464, 0.804) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.928, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.226, -0.536) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.577, -1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{10}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {4};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {3};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.089, -0.434) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.739, 0.72) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.331, 0.574) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.662, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.254, -1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.42, 0.14) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{11}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {3};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {3};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, -0.733) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.063, 0.914) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.483, 0.836) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.966, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.07, -0.981) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.316, -0.037) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{12}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {3};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {4};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}\\ \hline
# \resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.133, -0.398) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.633, 0.602) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.439, 0.562) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.593, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.156, -1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.11, 0.234) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{13}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {2};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {4};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (5);
#         \draw (2) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.85, -0.714) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.854, 0.965) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.816, 0.57) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.062, -0.93) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.174, 0.108) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{14}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {2};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {5};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (5);
#         \draw (2) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.166, -0.436) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.512, 0.483) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.291, 0.766) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.704, 0.021) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.38, -1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.063, 0.166) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{15}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {5};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (5);
#         \draw (2) to (5);
#         \draw (3) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.762, -0.53) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.707, 0.747) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.521, 0.902) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, -0.239) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.077, -0.925) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.026, 0.046) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{16}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {6};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (5);
#         \draw (2) to (5);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, -0.827) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (-0.293, 0.832) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (0.293, 0.832) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, -0.827) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.345, -0.004) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.345, -0.004) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{17}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {2};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {4};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (1) to (4);
#         \draw (2) to (5);
#         \draw (3) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, -0.689) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (1.0, 0.689) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-1.0, 0.689) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, -0.689) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.451, 0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.451, 0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{18}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {5};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (1) to (4);
#         \draw (2) to (5);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}\\ \hline
# \resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.629, -0.385) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.549, 1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.738, -0.623) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.716, 0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.364, 0.29) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.088, -0.281) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{19}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {2};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {5};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (2) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.102, -0.009) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (1.0, -0.091) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.607, 0.456) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.679, -0.339) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.554, -0.05) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.37, 0.034) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{20}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {5};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (2) to (5);
#         \draw (3) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.216, -0.48) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (1.0, 0.323) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.604, 0.552) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.769, -0.459) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.404, 0.088) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.247, -0.024) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{21}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {6};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (2) to (5);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, -0.121) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.129, 0.382) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.489, 0.847) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.978, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.267, -0.303) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.604, -0.806) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{22}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {3};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {4};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (1) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, -0.241) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (-0.008, 0.406) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.431, 0.746) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.861, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.102, -0.294) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.402, -0.618) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{23}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {3};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {5};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.034, -0.723) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.84, 0.321) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.86, 0.801) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.887, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (1.0, -0.635) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.128, 0.236) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{24}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {2};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {5};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (5);
#       \end{scope}
#     \end{tikzpicture}}\\ \hline
# \resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.977, -0.655) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.796, 0.552) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.997, 0.524) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.231, -0.584) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.006, 0.163) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{25}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {2};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {6};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.086, -0.632) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.611, 0.182) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.36, 0.935) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, -0.056) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.875, -0.565) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.212, 0.137) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{26}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {6};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (5);
#         \draw (3) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.803, -0.456) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.61, 0.351) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.477, 0.945) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, -0.328) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.207, -0.584) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.143, 0.072) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{27}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {7};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (5);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (-0.385, -0.054) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.385, 0.054) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.141, 1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (0.141, -1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.063, 0.445) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.063, -0.445) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{28}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {6};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (4);
#         \draw (3) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.567, -0.329) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.561, 0.339) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.502, 0.992) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.485, -1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.073, 0.334) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.068, -0.335) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{29}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {7};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (4);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.572, -0.808) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.516, 1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.585, -0.435) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.969, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.138, 0.241) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.604, 0.002) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{30}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {2};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {6};
#       \begin{scope}[-]
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (4);
#         \draw (2) to (5);
#       \end{scope}
#     \end{tikzpicture}}\\ \hline
# \resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.89, -0.838) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.311, 0.943) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
# ...
#         (-0.463, 0.865) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, 0.004) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.495, -0.858) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.504, -0.864) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{148}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {False};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {13};
#       \begin{scope}[-]
#         \draw (0) to (2);
#         \draw (0) to (3);
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (3);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (3);
#         \draw (2) to (4);
#         \draw (2) to (5);
#         \draw (3) to (4);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.604, -0.597) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (-0.431, 1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (0.759, 0.39) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.856, -0.226) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.022, 0.235) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (-0.099, -0.802) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{149}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {False};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {11};
#       \begin{scope}[-]
#         \draw (0) to (2);
#         \draw (0) to (3);
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (2);
#         \draw (1) to (3);
#         \draw (1) to (4);
#         \draw (2) to (4);
#         \draw (2) to (5);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (-0.386, 0.107) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.241, 0.32) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.348, -0.535) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.34, 1.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (0.231, -0.679) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.602, -0.212) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{150}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {False};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {11};
#       \begin{scope}[-]
#         \draw (0) to (2);
#         \draw (0) to (3);
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (2);
#         \draw (1) to (3);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (4);
#         \draw (2) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}\\ \hline
# \resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, 0.026) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.523, 0.853) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.526, 0.867) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.988, -0.002) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.496, -0.855) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.488, -0.889) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{151}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {11};
#       \begin{scope}[-]
#         \draw (0) to (2);
#         \draw (0) to (3);
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (2);
#         \draw (1) to (3);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (4);
#         \draw (2) to (5);
#         \draw (3) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, 0.032) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.529, 0.859) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.534, 0.877) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-0.984, -0.004) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.532, -0.86) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.522, -0.903) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{152}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {False};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {12};
#       \begin{scope}[-]
#         \draw (0) to (2);
#         \draw (0) to (3);
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (2);
#         \draw (1) to (3);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (4);
#         \draw (2) to (5);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, 0.025) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.522, 0.853) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.522, 0.853) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, 0.025) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.478, -0.879) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.478, -0.879) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{153}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {True};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {12};
#       \begin{scope}[-]
#         \draw (0) to (2);
#         \draw (0) to (3);
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (2);
#         \draw (1) to (3);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (4);
#         \draw (2) to (5);
#         \draw (3) to (4);
#         \draw (3) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, 0.032) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.53, 0.862) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.53, 0.862) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, 0.032) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.521, -0.894) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.521, -0.894) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{154}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {False};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {13};
#       \begin{scope}[-]
#         \draw (0) to (2);
#         \draw (0) to (3);
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (2);
#         \draw (1) to (3);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (4);
#         \draw (2) to (5);
#         \draw (3) to (4);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (0.973, 0.036) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.517, 0.825) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.501, 0.879) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, 0.001) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.499, -0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.51, -0.874) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{155}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {False};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {14};
#       \begin{scope}[-]
#         \draw (0) to (2);
#         \draw (0) to (3);
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (2);
#         \draw (1) to (3);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (3);
#         \draw (2) to (4);
#         \draw (2) to (5);
#         \draw (3) to (4);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}&\resizebox{1in}{!}{\begin{tikzpicture}
#       \draw
#         (1.0, 0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (0){}
#         (0.5, 0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (1){}
#         (-0.5, 0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (2){}
#         (-1.0, -0.0) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (3){}
#         (-0.5, -0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (4){}
#         (0.5, -0.866) node[draw=black,fill=black!0,shape=circle,text=black,inner sep=0pt,minimum size=4pt] (5){};
#       \draw
#         (0.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](6) {\textbf{$G_{156}$}};
#       \draw
#         (-1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](7) {False};
#       \draw
#         (-1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](8) {6};
#       \draw
#         (1.0,-1.15) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](9) {1};
#       \draw
#         (1.0,1.35) node[shape=circle,text=black,inner sep=0pt,minimum size=4pt,fill opacity=0,text opacity=1](10) {15};
#       \begin{scope}[-]
#         \draw (0) to (1);
#         \draw (0) to (2);
#         \draw (0) to (3);
#         \draw (0) to (4);
#         \draw (0) to (5);
#         \draw (1) to (2);
#         \draw (1) to (3);
#         \draw (1) to (4);
#         \draw (1) to (5);
#         \draw (2) to (3);
#         \draw (2) to (4);
#         \draw (2) to (5);
#         \draw (3) to (4);
#         \draw (3) to (5);
#         \draw (4) to (5);
#       \end{scope}
#     \end{tikzpicture}}
# \\ \hline
# \end{longtable}
